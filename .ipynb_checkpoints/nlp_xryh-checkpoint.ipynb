# %%
import os
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'
print("✓ 已设置国内镜像源")
print(f"当前环境: {os.environ.get('CONDA_DEFAULT_ENV', 'Unknown')}")
# Out:
# ✓ 已设置国内镜像源
# 当前环境: nlp_xryh

# %%
import transformers
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

print("✓ 依赖库导入成功")
print(f"transformers版本: {transformers.__version__}")
print(f"torch版本: {torch.__version__}")
# Out:
# ✓ 依赖库导入成功
# transformers版本: 4.57.6
# torch版本: 2.8.0+cpu

# %%
model_name = "uer/gpt2-chinese-cluecorpussmall"
print("正在下载模型（首次运行需要2-5分钟）...")

model = AutoModelForCausalLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

print(f"\n✓ 模型加载成功")
print(f"模型名称: {model_name}")
# Out:
# 正在下载模型（首次运行需要2-5分钟）...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# D:\ANACONDA\envs\nlp_xryh\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\MR\.cache\huggingface\hub\models--uer--gpt2-chinese-cluecorpussmall. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# ✓ 模型加载成功
# 模型名称: uer/gpt2-chinese-cluecorpussmall

# %%
generator = pipeline("text-generation", 
                     model=model, 
                     tokenizer=tokenizer, 
                     device=-1)
print("✓ 文本生成器已就绪")
# Out:
# Device set to use cpu
# ✓ 文本生成器已就绪

# %%
input_text = "有一天，城市突然停电了"

print("="*60)
print(f"输入: {input_text}")
print("="*60)
print("正在生成续写...\n")

outputs = generator(
    input_text,
    max_new_tokens=200,      
    do_sample=True,
    temperature=0.6,          
    top_p=0.85,              
    top_k=50,              
    repetition_penalty=1.2,  
    pad_token_id=tokenizer.eos_token_id
)

result = outputs[0]['generated_text']
print(f"续写结果:\n{result}")
print("="*60)
print(f"生成字符数: {len(result) - len(input_text)}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ============================================================
# 输入: 有一天，城市突然停电了
# ============================================================
# 正在生成续写...
#
# 续写结果:
# 有一天，城市突然停电了 ！ 这 些 天 ， 你 是 否 在 想 ： 如 果 没 有 房 子 的 话 ， 我 们 能 不 能 活 下 去 ？ 如 果 没 有 车 子 的 话 ， 我 们 能 不 能 活 得 更 好 ？ 如 果 没 有 车 子 的 话 ， 我 们 能 不 能 活 得 更 长 久 ？ 如 果 没 有 车 子 的 话 ， 我 们 能 不 能 活 得 更 久 远 ？ 现 实 生 活 中 ， 很 多 人 都 是 无 所 事 事 ， 无 聊 到 极 点 。 但 有 时 候 ， 我 们 却 被 迫 面 对 这 个 世 界 。 当 然 ， 也 有 例 外 。 有 一 次 我 和 朋 友 们 聚 会 ， 他 们 坐 在 大 厅 里 喝 酒 ， 其 乐 融 融 地 聊 着 天 ， 我 们 就 感 觉 到 了 一 种 孤 独 。 有 时 候 ， 我 们 自 己 的 身 体 也 需 要 别 人 来 照 顾 。 有 一 次
# ============================================================
# 生成字符数: 400
